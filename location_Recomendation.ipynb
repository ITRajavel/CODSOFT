# %% [markdown]
# <a href="https://colab.research.google.com/github/ITRajavel/CODSOFT/blob/main/location_Recomendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')



from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from geopy.geocoders import Nominatim

import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans
df = pd.read_csv('/content/locations.csv',sep=',')

# %%
#geopy in action
country = 'India'
city_names = df['location']

longitude =[]
latitude =[]
geolocator = Nominatim(user_agent="Trips")

for c in city_names.values:
    location = geolocator.geocode(c+','+ country)
    latitude.append(location.latitude)
    longitude.append(location.longitude)

# %%
df['latitude']=latitude
df['longitude']=longitude

# %%
l2=df.iloc[:,-1:-3:-1]
l2
# Out:
#     longitude   latitude
# 0   74.820444  34.074744
# 1   70.802838  22.305326
# 2   73.854454  18.521428
# 3   77.590082  12.976794
# 4   78.474061  17.360589
# 5   81.373285  21.212068
# 6   80.934600  26.838100
# 7   86.974659  23.687130
# 8   86.202958  22.801519
# 9   91.282382  23.831238
# 10  73.790236  20.011247
# 11  75.851601  30.909016
# 12  77.708101  28.982653
# 13  83.007629  25.335649
# 14  80.321759  26.460914
# 15  78.009816  27.175255
# 16  78.157363  26.203725
# 17  76.245444   9.967428
# 18  75.373797  11.876384
# 19  80.270186  13.083694
# 20  78.114098   9.926115
# 21  70.802838  22.305326
# 22  73.854454  18.521428
# 23  77.590082  12.976794
# 24  78.474061  17.360589
# 25  81.373285  21.212068
# 26  80.934600  26.838100
# 27  86.974659  23.687130
# 28  86.202958  22.801519
# 29  80.270186  13.083694

# %%
kmeans=KMeans(5)
kmeans.fit(l2)

identified_clusters = kmeans.fit_predict(l2)
identified_clusters = list(identified_clusters)
identified_clusters
# Out:
# [3,
#  2,
#  2,
#  1,
#  1,
#  0,
#  0,
#  4,
#  4,
#  4,
#  2,
#  3,
#  3,
#  0,
#  0,
#  3,
#  0,
#  1,
#  1,
#  1,
#  1,
#  2,
#  2,
#  1,
#  1,
#  0,
#  0,
#  4,
#  4,
#  1]

# %%
df['loc_clusters'] = identified_clusters
df
# Out:
#       location   latitude  longitude  loc_clusters
# 0     Srinagar  34.074744  74.820444             3
# 1       Rajkot  22.305326  70.802838             2
# 2         Pune  18.521428  73.854454             2
# 3    Bengaluru  12.976794  77.590082             1
# 4    Hyderabad  17.360589  78.474061             1
# 5       Bhilai  21.212068  81.373285             0
# 6      Lucknow  26.838100  80.934600             0
# 7      Asansol  23.687130  86.974659             4
# 8   Jamshedpur  22.801519  86.202958             4
# 9     Agartala  23.831238  91.282382             4
# 10      Nashik  20.011247  73.790236             2
# 11    Ludhiana  30.909016  75.851601             3
# 12      Meerut  28.982653  77.708101             3
# 13    Varanasi  25.335649  83.007629             0
# 14      Kanpur  26.460914  80.321759             0
# 15        Agra  27.175255  78.009816             3
# 16     Gwalior  26.203725  78.157363             0
# 17       Kochi   9.967428  76.245444             1
# 18      Kannur  11.876384  75.373797             1
# 19     Chennai  13.083694  80.270186             1
# 20     Madurai   9.926115  78.114098             1
# 21      Rajkot  22.305326  70.802838             2
# 22        Pune  18.521428  73.854454             2
# 23   Bengaluru  12.976794  77.590082             1
# 24   Hyderabad  17.360589  78.474061             1
# 25      Bhilai  21.212068  81.373285             0
# 26     Lucknow  26.838100  80.934600             0
# 27     Asansol  23.687130  86.974659             4
# 28  Jamshedpur  22.801519  86.202958             4
# 29     Chennai  13.083694  80.270186             1

# %%
input_city = input("Enter a city name:")
cluster = df.loc[df['location'] == input_city, 'loc_clusters']
cluster
cluster = cluster.iloc[0]
cities = df.loc[df['loc_clusters']==cluster,'location']
cities

for c in range(len(cities)):
  if cities.iloc[c]== input_city:
       continue
  else:
    print(cities.iloc[c])
# Out:
# Enter a city name:Lucknow
# Bhilai
# Varanasi
# Kanpur
# Gwalior
# Bhilai
